# %% [markdown]
# # Семинар 1. Практикум по основам Python
#
# ## 🎯 Цели семинара
# - Закрепить знания по синтаксису Python
# - Попрактиковаться в написании функций и работе со структурами данных
# - Научиться решать типовые задачи на Python
# - Подготовиться к домашнему заданию
#
# ---
#
# ## 📝 Разминка (3 задачи)
#
# ### Задача 1: Калькулятор BMI
# **Уровень:** Начальный
#
# Напишите функцию `calculate_bmi(weight, height)`, которая:
# - Принимает вес в килограммах и рост в метрах
# - Рассчитывает индекс массы тела: `BMI = вес / рост²`
# - Возвращает кортеж `(bmi_value, category)`, где `category` определяется так:
#   - `"Недостаточный вес"` если BMI < 18.5
#   - `"Нормальный вес"` если 18.5 ≤ BMI < 25
#   - `"Избыточный вес"` если 25 ≤ BMI < 30
#   - `"Ожирение"` если BMI ≥ 30
#
# **Пример:**
# ```python
# >>> calculate_bmi(70, 1.75)
# (22.86, "Нормальный вес")
# ```
#
# ---
#
# ### Задача 2: Анализатор текста
# **Уровень:** Начальный
#
# Напишите функцию `analyze_text(text)`, которая:
# - Принимает строку текста
# - Возвращает словарь со следующей статистикой:
#   - `"word_count"`: количество слов (разделитель - пробел)
#   - `"char_count_no_spaces"`: количество символов без пробелов
#   - `"longest_word"`: самое длинное слово
#   - `"average_word_length"`: средняя длина слова
#   - `"uppercase_count"`: количество символов в верхнем регистре
#
# **Пример:**
# ```python
# >>> analyze_text("Python - это мощный язык программирования!")
# {
#     'word_count': 5,
#     'char_count_no_spaces': 32,
#     'longest_word': 'программирования',
#     'average_word_length': 6.4,
#     'uppercase_count': 1
# }
# ```
#
# ---
#
# ### Задача 3: Конвертер температур
# **Уровень:** Начальный
#
# Создайте модуль `temperature_converter.py` с тремя функциями:
# 1. `celsius_to_fahrenheit(celsius)` - конвертация из Цельсия в Фаренгейт
# 2. `fahrenheit_to_celsius(fahrenheit)` - конвертация из Фаренгейта в Цельсий
# 3. `celsius_to_kelvin(celsius)` - конвертация из Цельсия в Кельвины
#
# **Формулы:**
# - °F = (°C × 9/5) + 32
# - °C = (°F - 32) × 5/9
# - K = °C + 273.15
#
# **Дополнительно:** Создайте функцию `convert_temperature(value, from_unit, to_unit)`, которая поддерживает все три шкалы ('C', 'F', 'K').
#
# ---
#
# ## 🧠 Для вдумчивых (2 сложные задачи)
#
# ### Задача 4: Генератор безопасных паролей
# **Уровень:** Продвинутый
#
# Создайте функцию `generate_password(length=12, use_special=True)`, которая:
# 1. Генерирует случайный пароль заданной длины
# 2. Обязательно включает:
#    - Минимум 2 заглавные буквы
#    - Минимум 2 строчные буквы
#    - Минимум 2 цифры
#    - Минимум 2 специальных символа (если `use_special=True`)
# 3. Гарантирует, что символы не идут подряд (не более 2 одинаковых типа подряд)
# 4. Возвращает кортеж `(password, strength)`, где `strength` оценивается по шкале от 1 до 5:
#    - 1: слабый (только буквы)
#    - 2: средний (буквы + цифры)
#    - 3: хороший (буквы + цифры + спецсимволы)
#    - 4: отличный (длина ≥ 14, все типы символов)
#    - 5: превосходный (длина ≥ 16, все типы, нет повторяющихся паттернов)
#
# **Подсказка:** Используйте модуль `random` или `secrets`.
#
# ---
#
# ### Задача 5: Валидатор математических выражений
# **Уровень:** Продвинутый
#
# Напишите функцию `validate_expression(expression)`, которая:
# 1. Принимает строку с математическим выражением (только `+`, `-`, `*`, `/`, скобки `()`, числа и пробелы)
# 2. Проверяет корректность выражения:
#    - Скобки сбалансированы
#    - Нет двух операторов подряд
#    - Нет деления на ноль в явном виде (`/0`)
#    - Числа записаны корректно (могут быть десятичными: `3.14`, `0.5`)
# 3. Если выражение корректно, возвращает `True` и результат вычисления (если возможно)
# 4. Если некорректно, возвращает `False` и строку с описанием ошибки
#
# **Пример:**
# ```python
# >>> validate_expression("(3 + 5) * 2 / 4")
# (True, 4.0)
#
# >>> validate_expression("3 + * 5")
# (False, "Два оператора подряд: '+' и '*'")
#
# >>> validate_expression("10 / 0")
# (False, "Деление на ноль")
# ```
#
# **Особое задание:** Реализуйте вычисление без использования `eval()`.
#
# ---

# %% [markdown]
# # Домашнее задание (2 задачи средней сложности)
#
# ### Задача 1: Калькулятор комплексных операций
# Создайте модуль `advanced_calculator.py` с функциями:
#
# 1. **`calculate_statistics(numbers)`** - принимает список чисел и возвращает словарь с:
#    - средним арифметическим
#    - медианой
#    - минимальным значением
#    - максимальным значением
#    - суммой всех элементов
#
# 2. **`process_string(text)`** - принимает строку и возвращает словарь с:
#    - количеством слов
#    - количеством предложений (разделитель - . ! ?)
#    - обратной строкой (слова в обратном порядке)
#    - частотой встречаемости каждой буквы (только буквы, без учёта регистра)
#
# 3. **`validate_password(password)`** - проверяет пароль на соответствие критериям:
#    - длина не менее 8 символов
#    - есть хотя бы одна цифра
#    - есть хотя бы одна заглавная буква
#    - есть хотя бы одна строчная буква
#    - есть хотя бы один специальный символ (!@#$%^&*)
#    Возвращает `(bool, list_of_errors)` - True/False и список ошибок, если есть.
#
# **Пример использования:**
# ```python
# >>> calculate_statistics([1, 2, 3, 4, 5])
# {'mean': 3.0, 'median': 3, 'min': 1, 'max': 5, 'sum': 15}
#
# >>> process_string("Привет, мир! Как дела?")
# {
#     'word_count': 5,
#     'sentence_count': 2,
#     'reversed': 'дела? Как мир! Привет,',
#     'letter_freq': {'п': 1, 'р': 2, 'и': 2, 'в': 1, 'е': 2, 'т': 1, 'м': 1, 'к': 2, 'а': 3, 'д': 1, 'л': 1}
# }
# ```
#
# ---
#
# ### Задача 2: Система учета книг в библиотеке
# Создайте программу для учета книг в библиотеке. Реализуйте следующие функции:
#
# 1. **`add_book(library, title, author, year, genre)`** - добавление новой книги
# 2. **`remove_book(library, title)`** - удаление книги по названию
# 3. **`find_books_by_author(library, author)`** - поиск всех книг автора
# 4. **`find_books_by_genre(library, genre)`** - поиск книг по жанру
# 5. **`get_books_published_after(library, year)`** - книги, опубликованные после указанного года
# 6. **`get_library_statistics(library)`** - статистика библиотеки:
#    - общее количество книг
#    - количество уникальных авторов
#    - самый популярный жанр
#    - самый старый год издания
#
# **Структура данных для библиотеки:**
# ```python
# library = [
#     {
#         "title": "Преступление и наказание",
#         "author": "Фёдор Достоевский",
#         "year": 1866,
#         "genre": "роман"
#     },
#     {
#         "title": "Мастер и Маргарита",
#         "author": "Михаил Булгаков",
#         "year": 1967,
#         "genre": "роман"
#     }
# ]
# ```
#
# **Требования:**
# - Все функции должны корректно обрабатывать пустые данные
# - Добавьте проверку на дубликаты при добавлении книги
# - Реализуйте функцию `display_books(books_list)` для красивого вывода списка книг
# - Сохраняйте данные в файл `library.json` и загружайте из него
#
# **Пример работы:**
# ```python
# >>> add_book(library, "1984", "Джордж Оруэлл", 1949, "антиутопия")
# Книга "1984" успешно добавлена!
#
# >>> find_books_by_genre(library, "роман")
# Найдено 2 книги в жанре "роман":
# 1. "Преступление и наказание" (Фёдор Достоевский, 1866)
# 2. "Мастер и Маргарита" (Михаил Булгаков, 1967)
# ```
#
# **Дополнительное задание (по желанию):**
# Добавьте систему рейтинга книг (от 1 до 5 звёзд) и функцию для получения топ-N книг по рейтингу.
#
# ---

# %% [markdown]
# ## 📋 Критерии оценки
#
# ### Обычные задачи (1-3):
# - Корректность решения: 60%
# - Эффективность кода: 20%
# - Читаемость и соответствие PEP 8: 20%
#
# ### Задачи для подумать (4-5):
# - Корректность: 40%
# - Обработка крайних случаев: 30%
# - Оптимизация: 20%
# - Читаемость кода: 10%
#
# ### Домашнее задание (6-7):
# - Полная реализация требований: 50%
# - Корректность работы: 30%
# - Обработка ошибок: 10%
# - Соответствие PEP 8: 10%
#
# ---
