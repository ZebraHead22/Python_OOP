# %% [markdown]
# # Семинар 4. Инкапсуляция по-питоньи — практикум для начинающих
#
# ## Ячейка 1: Заголовок и простые цели (Markdown)
#
#
# # Семинар 4. Инкапсуляция по-питоньи — практикум
#
# ## 🎯 Что будем делать сегодня?
# 1. Научимся использовать `_protected` и `__private`
# 2. Попробуем `@property` на простых примерах
# 3. Поймём разницу между `@classmethod` и `@staticmethod`
# 4. Решим несколько небольших задач
#
#
# ---
#
# ## Ячейка 2: Простая задача — "Секретный ящик" (Markdown)
#
#
# ## 🧩 Разбираем первую задачу вместе
#
# ### Задача: "Секретный ящик"
# Создайте класс `SecretBox`, который хранит секретное сообщение.
# - Сообщение должно быть защищено от прямого доступа
# - Можно получить сообщение только с правильным паролем
# - Можно изменить сообщение только с правильным паролем
#
# **Простая версия — сделаем вместе:**
#
#
# ---
#
# ## Ячейка 3: Код задачи "Секретный ящик" (Python)
#
# ```python
# # Разбираем вместе: Секретный ящик
# print("🔐 Простая задача: Секретный ящик\n")
#
# class SecretBox:
#     def __init__(self, password):
#         # Публичный атрибут - пароль
#         self.password = password
#
#         # Защищённый атрибут - сообщение (одно подчёркивание)
#         self._message = "Секретное сообщение"
#
#         # Приватный атрибут - счётчик попыток (два подчёркивания)
#         self.__attempts = 0
#
#     def get_message(self, user_password):
#         """Получить сообщение, если пароль верный"""
#         if user_password == self.password:
#             print("Пароль верный! Сообщение:", self._message)
#             return self._message
#         else:
#             self.__attempts += 1
#             print(f"Неверный пароль! Попыток: {self.__attempts}")
#             return None
#
#     def change_password(self, old_password, new_password):
#         """Изменить пароль"""
#         if old_password == self.password:
#             self.password = new_password
#             print("Пароль изменён!")
#             return True
#         print("Старый пароль неверен!")
#         return False
#
# # Давайте создадим ящик и попробуем с ним поработать
# print("1. Создаём секретный ящик:")
# my_box = SecretBox("1234")
# print(f"   Пароль ящика: {my_box.password}")
# print()
#
# print("2. Пытаемся получить сообщение:")
# # Верный пароль
# my_box.get_message("1234")
#
# # Неверный пароль
# my_box.get_message("0000")
# print()
#
# print("3. Меняем пароль:")
# my_box.change_password("1234", "новыйпароль")
# print(f"   Новый пароль: {my_box.password}")
# print()
#
# print("4. Что такое _protected и __private?")
# print("   _message - защищённый атрибут (можно прочитать, но лучше не трогать)")
# print("   __attempts - приватный атрибут (Python скрыл его имя)")
# print()
#
# print("5. Попробуем получить доступ к атрибутам напрямую:")
# print(f"   my_box._message = '{my_box._message}'")
# print("   Можно прочитать, но не нужно!")
#
# try:
#     print(f"   my_box.__attempts = {my_box.__attempts}")
# except AttributeError:
#     print("   Ошибка! __attempts недоступен напрямую")
#
# print("\nПоздравляю! Вы создали свой первый класс с инкапсуляцией! 🎉")
# ```
#
# ---
#
# ## Ячейка 4: Задачи для самостоятельного решения (Markdown)
#
#
# ## 📝 Простые задачи для самостоятельного решения
#
# ### Задача 1: "Умная корзина покупок"
# Создайте класс `ShoppingCart`, который:
# 1. Хранит список товаров (публичный атрибут)
# 2. Хранит общую сумму в защищённом атрибуте `_total`
# 3. Считает количество добавлений в приватном атрибуте `__add_count`
# 4. Добавляет товар методом `add_item(name, price)`
# 5. Показывает итог методом `get_total()`
#
# **Требования:**
# - При добавлении товара увеличивается `__add_count`
# - Метод `get_total()` возвращает защищённую сумму `_total`
# - Прямой доступ к `_total` и `__add_count` не рекомендуется
#
# ```python
# # Пример использования:
# cart = ShoppingCart()
# cart.add_item("Яблоки", 100)
# cart.add_item("Хлеб", 50)
# print(cart.get_total())  # 150
# ```
#
# ### Задача 2: "Температурный датчик"
# Создайте класс `Thermometer`, который:
# 1. Хранит температуру в градусах Цельсия
# 2. Использует `@property` для доступа к температуре
# 3. Запрещает установку температуры ниже -273.15°C (абсолютный ноль)
# 4. Имеет метод `to_fahrenheit()` для конвертации в Фаренгейты
#
# ```python
# # Пример использования:
# thermo = Thermometer(25)
# print(thermo.temperature)  # 25
# thermo.temperature = 30    # OK
# thermo.temperature = -300  # Ошибка!
# print(thermo.to_fahrenheit())  # 77.0
# ```
#
# ### Задача 3: "Счётчик студентов"
# Создайте класс `StudentCounter`, который:
# 1. Использует `@classmethod` для подсчёта всех созданных студентов
# 2. Использует `@staticmethod` для проверки корректности имени
# 3. Хранит имя студента в публичном атрибуте
# 4. При создании увеличивает общий счётчик студентов
#
# ```python
# # Пример использования:
# student1 = StudentCounter("Анна")
# student2 = StudentCounter("Иван")
# print(StudentCounter.get_count())  # 2
# print(StudentCounter.is_valid_name("А123"))  # False
# ```
#
# ### Задача 4: "Простой банковский счёт"
# Создайте класс `SimpleBankAccount`, который:
# 1. Хранит баланс в защищённом атрибуте `_balance`
# 2. Использует `@property` для доступа к балансу
# 3. Имеет методы `deposit(amount)` и `withdraw(amount)`
# 4. Не позволяет снять больше, чем есть на счету
#
# ```python
# # Пример использования:
# account = SimpleBankAccount(1000)
# account.deposit(500)
# account.withdraw(200)
# print(account.balance)  # 1300 (через property)
# ```
#
# **Совет:** Начинайте с конструктора `__init__`, потом добавляйте методы по одному.
# ```
#
# ---
#
# ## Ячейка 5: Задачи "для подумать" (Markdown)
#
# ```markdown
# ## 🤔 Задачи "для подумать" (посложнее)
#
# ### Задача 5: "Калькулятор с историей"
# Создайте класс `CalculatorWithHistory`, который:
# 1. Выполняет простые операции: +, -, *, /
# 2. Хранит историю операций в защищённом списке `_history`
# 3. Использует `@property` для получения последнего результата
# 4. Использует `@staticmethod` для проверки, является ли строка числом
# 5. Не позволяет делить на ноль
#
# **Подсказка:** История может быть списком строк: ["2 + 2 = 4", "4 * 3 = 12"]
#
# ```python
# calc = CalculatorWithHistory()
# calc.add(5, 3)      # 8
# calc.multiply(2, 4) # 8
# print(calc.last_result)  # 8
# print(calc.get_history()) # ["5 + 3 = 8", "2 * 4 = 8"]
# ```
#
# ### Задача 6: "Игральный кубик"
# Создайте класс `Dice` (игральный кубик), который:
# 1. Использует `__private` для хранения текущего значения
# 2. Имеет метод `roll()` для броска кубика
# 3. Использует `@property` для получения текущего значения
# 4. Использует `@classmethod` для создания кубика с разным количеством граней
# 5. Считает количество бросков
#
# ```python
# # Обычный кубик (6 граней)
# dice1 = Dice()
# dice1.roll()
# print(dice1.value)  # случайное число от 1 до 6
#
# # Кубик с 20 гранями
# dice2 = Dice.create_d20()
# dice2.roll()
# print(dice2.value)  # случайное число от 1 до 20
# ```
#
# **Не волнуйтесь, если не получается!** Главное — попробовать. Можно задавать вопросы!
# ```
#
# ---
#
# ## Ячейка 6: Домашнее задание (Markdown)
#
# ```markdown
# ## 🏠 Домашнее задание (2 задачи)
#
# ### Задача 1: "Умный будильник"
# Создайте класс `AlarmClock`, который:
# 1. Хранит текущее время и время будильника
# 2. Использует `_protected` для хранения времени будильника
# 3. Использует `@property` для времени (с проверкой формата "ЧЧ:ММ")
# 4. Имеет методы:
#    - `set_time(time)` - установить текущее время
#    - `set_alarm(time)` - установить будильник
#    - `check_alarm()` - проверить, не пора ли звонить
#
# ```python
# # Пример:
# alarm = AlarmClock()
# alarm.set_time("08:00")
# alarm.set_alarm("08:30")
# print(alarm.check_alarm())  # False
#
# alarm.set_time("08:30")
# print(alarm.check_alarm())  # True
# ```
#
# ### Задача 2: "Библиотечная книга"
# Создайте класс `LibraryBook`, который:
# 1. Хранит название, автора и статус (доступна/выдана)
# 2. Использует `@property` для статуса (только чтение)
# 3. Использует `__private` для ID книги
# 4. Имеет методы:
#    - `borrow()` - выдать книгу
#    - `return_book()` - вернуть книгу
#    - `get_info()` - получить информацию о книге
# 5. Использует `@classmethod` для создания книги из строки "Автор - Название"
#
# ```python
# # Пример:
# book = LibraryBook("Преступление и наказание", "Достоевский")
# book.borrow()
# print(book.status)  # "выдана"
# book.return_book()
# print(book.status)  # "доступна"
#
# book2 = LibraryBook.from_string("Толстой - Война и мир")
# ```
#
# **Советы:**
# 1. Начните с конструктора `__init__`
# 2. Добавляйте по одному методу и тестируйте
# 3. Используйте `print()` чтобы видеть, что происходит
# 4. Не бойтесь ошибаться — это нормально!
#
#
# ---
#
# ## Ячейка 7: Шаблоны для начала работы (Python)
#
# ```python
# # Шаблоны для начала работы с задачами
#
# print("📝 Шаблоны для начала работы\n")
#
# # Шаблон для задачи 1 (Корзина покупок)
# print("1. Шаблон для задачи 'Корзина покупок':")
# print("""
# class ShoppingCart:
#     def __init__(self):
#         self.items = []           # Публичный список товаров
#         self._total = 0           # Защищённая общая сумма
#         self.__add_count = 0      # Приватный счётчик добавлений
#
#     def add_item(self, name, price):
#         # TODO: добавьте товар в список
#         # TODO: увеличьте общую сумму
#         # TODO: увеличьте счётчик добавлений
#         pass
#
#     def get_total(self):
#         # TODO: верните общую сумму
#         pass
# """)
# print()
#
# # Шаблон для задачи 2 (Температурный датчик)
# print("2. Шаблон для задачи 'Температурный датчик':")
# print("""
# class Thermometer:
#     def __init__(self, temperature):
#         self._temperature = temperature  # Защищённая температура
#
#     @property
#     def temperature(self):
#         # Геттер: возвращает температуру
#         return self._temperature
#
#     @temperature.setter
#     def temperature(self, value):
#         # Сеттер: проверяет, что температура не ниже -273.15
#         if value < -273.15:
#             print("Ошибка: температура не может быть ниже абсолютного нуля!")
#         else:
#             self._temperature = value
#
#     def to_fahrenheit(self):
#         # Конвертирует в Фаренгейты: °F = °C × 9/5 + 32
#         return self._temperature * 9/5 + 32
# """)
# print()
#
# # Шаблон для задачи 3 (Счётчик студентов)
# print("3. Шаблон для задачи 'Счётчик студентов':")
# print("""
# class StudentCounter:
#     # Атрибут класса (общий для всех студентов)
#     _total_students = 0
#
#     def __init__(self, name):
#         self.name = name
#         # Увеличиваем общий счётчик
#         StudentCounter._total_students += 1
#
#     @classmethod
#     def get_count(cls):
#         # Возвращает общее количество студентов
#         return cls._total_students
#
#     @staticmethod
#     def is_valid_name(name):
#         # Проверяет, что имя не пустое и состоит из букв
#         if not name or not name.isalpha():
#             return False
#         return True
# """)
# print()
#
# print("💡 Начните с этих шаблонов и дополняйте их по мере решения!")
# ```
#
# ---
#
# ## Ячейка 8: Проверка решений (Python)
#
# ```python
# # Простая проверка для задачи 1 (Корзина покупок)
# print("✅ Проверка для задачи 1 (Корзина покупок):")
#
# class ShoppingCart:
#     def __init__(self):
#         self.items = []
#         self._total = 0
#         self.__add_count = 0
#
#     def add_item(self, name, price):
#         self.items.append(name)
#         self._total += price
#         self.__add_count += 1
#
#     def get_total(self):
#         return self._total
#
# # Проверяем
# cart = ShoppingCart()
# cart.add_item("Яблоки", 100)
# cart.add_item("Хлеб", 50)
#
# print(f"1. Товары: {cart.items}")
# print(f"2. Общая сумма: {cart.get_total()}")
# print(f"3. Пытаемся получить доступ к _total: {cart._total}")
# print(f"4. Пытаемся получить доступ к __add_count: ", end="")
# try:
#     print(cart.__add_count)
# except AttributeError:
#     print("Нельзя! Python скрыл это имя")
# print()
#
# # Простая проверка для задачи 2 (Температурный датчик)
# print("✅ Проверка для задачи 2 (Температурный датчик):")
#
# class Thermometer:
#     def __init__(self, temperature):
#         self._temperature = temperature
#
#     @property
#     def temperature(self):
#         return self._temperature
#
#     @temperature.setter
#     def temperature(self, value):
#         if value < -273.15:
#             print("Ошибка: температура не может быть ниже -273.15!")
#         else:
#             self._temperature = value
#
#     def to_fahrenheit(self):
#         return self._temperature * 9/5 + 32
#
# # Проверяем
# thermo = Thermometer(25)
# print(f"1. Начальная температура: {thermo.temperature}")
# thermo.temperature = 30
# print(f"2. После изменения: {thermo.temperature}")
# print(f"3. Попытка установить -300: ", end="")
# thermo.temperature = -300
# print(f"4. Температура в Фаренгейтах: {thermo.to_fahrenheit():.1f}")
# print()
#
# print("🎉 Если у вас получилось похоже — вы молодец!")
# print("Если нет — не расстраивайтесь, задавайте вопросы!")
# ```
#
# ---
#
# ## Ячейка 9: Частые вопросы и ошибки (Markdown)
#
#
# ## ❓ Частые вопросы и ошибки
#
# ### Вопрос 1: Зачем нужно self._атрибут если к нему всё равно можно получить доступ?
# **Ответ:** `_атрибут` — это соглашение. Мы говорим другим программистам: "Это внутренняя переменная, лучше её не трогать напрямую". Python доверяет нам, что мы будем соблюдать это правило.
#
# ### Вопрос 2: В чём разница между @property и обычным методом?
# ```python
# # С @property
# class Example1:
#     @property
#     def value(self):
#         return self._value
#
# obj = Example1()
# print(obj.value)  # Без скобок!
#
# # Без @property
# class Example2:
#     def get_value(self):
#         return self._value
#
# obj = Example2()
# print(obj.get_value())  # Со скобками!
# ```
#
# ### Вопрос 3: Когда использовать @classmethod, а когда @staticmethod?
# - **`@classmethod`** — когда нужен доступ к классу (например, для создания объекта)
# - **`@staticmethod`** — когда не нужен доступ ни к чему (просто функция в классе)
#
# ### Частые ошибки:
# 1. **Забыли self в методах:**
# ```python
# class Wrong:
#     def method():  # ❌ Нет self!
#         pass
#
# class Right:
#     def method(self):  # ✅ Есть self!
#         pass
# ```
#
# 2. **Перепутали self и cls:**
# ```python
# class Wrong:
#     @classmethod
#     def method(self):  # ❌ Должно быть cls!
#         pass
#
# class Right:
#     @classmethod
#     def method(cls):  # ✅ Правильно!
#         pass
# ```
#
# 3. **Использовали property как метод:**
# ```python
# obj = MyClass()
# print(obj.property())  # ❌ Со скобками
# print(obj.property)    # ✅ Без скобок
# ```
#
# ### Помните:
# 1. **Не бойтесь ошибаться** — все ошибаются
# 2. **Задавайте вопросы** — если что-то непонятно
# 3. **Начинайте с простого** — потом усложняйте
# 4. **Тестируйте по частям** — не пишите весь код сразу
#
#
# ---
#
# ## Ячейка 10: Итоги и поддержка (Markdown)
#
#
# ## 🎯 Что мы сегодня сделали?
#
# 1. **Узнали про инкапсуляцию** — как защищать данные в классах
# 2. **Попробовали `_protected`** — для "внутреннего использования"
# 3. **Попробовали `__private`** — для скрытых данных
# 4. **Использовали `@property`** — для контролируемого доступа
# 5. **Разобрали `@classmethod` и `@staticmethod`**
#
# ## 📚 Что почитать дополнительно?
#
# 1. **Официальная документация:**
#    - [Python Classes](https://docs.python.org/3/tutorial/classes.html)
#    - [@property](https://docs.python.org/3/library/functions.html#property)
#
# 2. **Простые примеры:**
#    - [Real Python: Python Properties](https://realpython.com/python-property/)
#    - [GeeksforGeeks: Encapsulation in Python](https://www.geeksforgeeks.org/encapsulation-in-python/)
#
# ## 💪 Несколько советов:
#
# 1. **Практикуйтесь понемногу каждый день** — лучше 30 минут каждый день, чем 5 часов в выходные
# 2. **Начинайте с простых задач** — не пытайтесь сделать всё идельно с первого раза
# 3. **Используйте print() для отладки** — смотрите, что происходит в коде
# 4. **Не сравнивайте себя с другими** — у всех разная скорость обучения
#
# ## 🆘 Если застряли:
#
# 1. **Перечитайте лекцию** — возможно, вы что-то пропустили
# 2. **Посмотрите примеры кода** — в лекции и этом семинаре
# 3. **Задавайте вопросы** — на следующем занятии или в чате
# 4. **Начните заново** — иногда проще переписать код с нуля
#
# ---
#
# <div style="background: #2b0101a8; padding: 15px; border-radius: 10px; border-left: 5px solid #2196F3;">
# <h3>🏆 Главное — понять основы!</h3>
# <p>Не нужно запоминать всё сразу. Главное — понять:</p>
# <ol>
# <li>Зачем нужна инкапсуляция</li>
# <li>Как использовать _ и __</li>
# <li>Зачем нужны @property, @classmethod, @staticmethod</li>
# </ol>
# <p>Всё остальное придёт с практикой! 💪</p>
# </div>
