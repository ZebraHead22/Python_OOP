# %% [markdown]
# # Магические методы (часть 1)
# ## __str__, __repr__, __eq__, __hash__, __len__
#
# Магические методы (dunder methods) — специальные методы в Python, которые начинаются и заканчиваются двумя подчёркиваниями. Они позволяют определять поведение объектов в различных ситуациях: вывод на экран, сравнение, использование в коллекциях и т.д.

# %%
# Простейший пример магического метода __str__
class SimpleClass:
    def __str__(self):
        return "Это моя строка"

obj = SimpleClass()
print(obj)  # Выведет: "Это моя строка"
print(str(obj))  # Тоже использует __str__

# %% [markdown]
# ## __str__ vs __repr__: в чем разница?
#
# **`__str__`** — для пользователей:
# - Используется функциями `str()`, `print()`, f-строками
# - Должен возвращать читаемое, "человеческое" представление
#
# **`__repr__`** — для разработчиков:
# - Используется функцией `repr()`, отладчиками, в интерактивном режиме
# - Должен возвращать однозначное представление, по которому можно воссоздать объект
# - Если `__str__` не определён, используется `__repr__`

# %%
# Пример с книгой: демонстрация разницы между __str__ и __repr__
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
    
    def __str__(self):
        """Для пользователей (читаемое представление)"""
        return f'Книга "{self.title}" - {self.author}'
    
    def __repr__(self):
        """Для разработчиков (однозначное представление)"""
        return f'Book("{self.title}", "{self.author}")'

# Демонстрация
book = Book("Преступление и наказание", "Достоевский")

print("str(book):", str(book))     # Книга "Преступление и наказание" - Достоевский
print("repr(book):", repr(book))   # Book("Преступление и наказание", "Достоевский")
print("Просто book:", book)        # Используется __str__

# %% [markdown]
# ## __eq__ — оператор сравнения (равенство)
#
# Метод `__eq__` определяет поведение оператора `==`. Он должен:
# 1. Принимать два аргумента: `self` и `other`
# 2. Возвращать `True` если объекты равны, `False` — если нет
# 3. Обычно проверяет равенство по значению, а не по идентичности (`is`)
#
# Также существует метод `__ne__` для оператора `!=`, но если он не определён, Python использует `not (self == other)`.

# %%
# Пример с вектором: сравнение объектов
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def __eq__(self, other):
        """Определяет поведение оператора =="""
        if not isinstance(other, Vector):
            return NotImplemented
        return self.x == other.x and self.y == other.y
    
    def __ne__(self, other):
        """Определяет поведение оператора !="""
        return not self.__eq__(other)

# Демонстрация
v1 = Vector(1, 2)
v2 = Vector(1, 2)
v3 = Vector(3, 4)

print(f"v1 == v2: {v1 == v2}")  # True - одинаковые координаты
print(f"v1 == v3: {v1 == v3}")  # False - разные координаты
print(f"v1 != v3: {v1 != v3}")  # True - использует __ne__

# %% [markdown]
# ## __hash__ — хеширование объектов
#
# Метод `__hash__` позволяет объектам быть элементами множеств (`set`) и ключами словарей (`dict`).
#
# **Важное правило:** если два объекта равны (`a == b`), то их хеши должны быть равны (`hash(a) == hash(b)`). Обратное не обязательно.
#
# Если переопределить `__eq__`, то `__hash__` автоматически становится `None`, и объект становится нехешируемым, если не переопределить `__hash__`.

# %%
# Пример со студентом: использование объектов как ключей словаря
class Student:
    def __init__(self, name, student_id):
        self.name = name
        self.id = student_id
    
    def __eq__(self, other):
        return self.id == other.id
    
    def __hash__(self):
        """Хэш должен быть одинаковым для равных объектов"""
        return hash(self.id)

# Демонстрация
s1 = Student("Анна", 123)
s2 = Student("Анна", 123)  # Тот же ID
s3 = Student("Иван", 456)  # Другой ID

print(f"hash(s1): {hash(s1)}")
print(f"hash(s2): {hash(s2)}")  # Одинаковый с s1, т.к. ID одинаковый
print(f"hash(s3): {hash(s3)}")

# Использование как ключей в словаре
students_dict = {s1: "отличник"}
print(f"s2 в словаре: {s2 in students_dict}")  # True, т.к. s1 == s2

# %% [markdown]
# ## __len__ — получение длины объекта
#
# Метод `__len__` позволяет использовать встроенную функцию `len()` с вашими объектами. Он должен возвращать неотрицательное целое число.
#
# Интересный факт: метод `__bool__`, который определяет истинность объекта в условных выражениях, по умолчанию вызывает `__len__` (если он определён) и считает объект `False`, если длина равна 0.

# %%
# Пример с плейлистом: объект-коллекция
class Playlist:
    def __init__(self):
        self.songs = []
    
    def add_song(self, song):
        self.songs.append(song)
    
    def __len__(self):
        """Возвращает количество элементов"""
        return len(self.songs)
    
    def __bool__(self):
        """Определяет поведение в булевом контексте"""
        return len(self) > 0

# Демонстрация
my_playlist = Playlist()
print(f"Начальная длина: {len(my_playlist)}")  # 0

my_playlist.add_song("Bohemian Rhapsody")
my_playlist.add_song("Stairway to Heaven")
print(f"После добавления: {len(my_playlist)}")  # 2

# Использование в условном выражении
if my_playlist:  # Вызывает __bool__, который использует __len__
    print("Плейлист не пустой")
else:
    print("Плейлист пустой")

# %% [markdown]
# ## Комплексный пример: класс Fraction (дробь)
#
# Давайте создадим класс для работы с дробями, который будет использовать все изученные магические методы. Это поможет увидеть, как они работают вместе.

# %%
class Fraction:
    """Класс для работы с дробями"""
    def __init__(self, numerator, denominator):
        self.numer = numerator
        self.denom = denominator
    
    def __str__(self):
        return f"{self.numer}/{self.denom}"
    
    def __repr__(self):
        return f"Fraction({self.numer}, {self.denom})"
    
    def __eq__(self, other):
        if not isinstance(other, Fraction):
            return False
        # Приводим к общему знаменателю: a/b == c/d если a*d == c*b
        return self.numer * other.denom == other.numer * self.denom
    
    def __hash__(self):
        # Хешируем кортеж из числителя и знаменателя
        return hash((self.numer, self.denom))
    
    def __len__(self):
        # Нестандартное использование: возвращаем сумму модулей
        return abs(self.numer) + abs(self.denom)

# Создаём дроби
f1 = Fraction(1, 2)
f2 = Fraction(2, 4)  # Эквивалентно 1/2
f3 = Fraction(3, 4)  # Другая дробь

print(f"str: {f1}")
print(f"repr: {repr(f1)}")
print(f"f1 == f2: {f1 == f2}")  # True, т.к. 1/2 == 2/4
print(f"f1 == f3: {f1 == f3}")  # False
print(f"hash(f1): {hash(f1)}")
print(f"len(f1): {len(f1)}")  # |1| + |2| = 3

# Использование в коллекциях
fractions_set = {f1, f2, f3}
print(f"Уникальных дробей в множестве: {len(fractions_set)}")  # 2 (f1 и f3 равны по __eq__)

# %% [markdown]
# ## Важные правила и предостережения
#
# 1. **Согласованность `__eq__` и `__hash__`**: Если `a == b`, то обязательно `hash(a) == hash(b)`. Обратное не требуется.
#
# 2. **Неизменяемость**: Если объект изменяемый, его хеш не должен меняться. Лучше не делать изменяемые объекты хешируемыми.
#
# 3. **Возвращаемые значения**: `__len__` должен возвращать неотрицательное целое, `__hash__` — целое число.
#
# 4. **Производительность**: `__hash__` должен быть быстрым, так как вызывается часто при работе со словарями и множествами.

# %%
# Демонстрация проблемы с изменяемыми объектами
class BadMutable:
    def __init__(self, value):
        self.value = value
    
    def __eq__(self, other):
        return self.value == other.value
    
    def __hash__(self):
        return hash(self.value)
    
    def change(self, new_value):
        self.value = new_value

# Проблема: объект может измениться после добавления в множество
obj = BadMutable(5)
my_set = {obj}
print(f"Объект в множестве: {obj in my_set}")  # True

obj.change(10)  # Меняем значение
print(f"Хеш изменился: {hash(obj)}")
print(f"Объект всё ещё в множестве? {obj in my_set}")  # Может быть False или ошибка

# Правильный подход: использовать только неизменяемые атрибуты для хеширования
class GoodImmutable:
    
    def __init__(self, value):
        self._value = value  # Защищённый атрибут
    
    @property
    def value(self):
        return self._value
    
    def __eq__(self, other):
        return self._value == other._value
    
    def __hash__(self):
        return hash(self._value)

# %% [markdown]
# ## Практические советы по использованию
#
# ### Когда использовать каждый метод:
# - **`__str__`** — когда нужен красивый вывод для пользователя (в интерфейсе, логах)
# - **`__repr__`** — для отладки, должен позволять воссоздать объект
# - **`__eq__`** — когда нужно сравнение по значению (а не по ссылке)
# - **`__hash__`** — когда объекты будут ключами словаря или элементами множества
# - **`__len__`** — для объектов-коллекций (списки, словари, множества)
#
# ### Рекомендации:
# 1. Всегда определяйте `__repr__` — это помогает при отладке
# 2. Если определили `__eq__`, определите и `__hash__` (или явно установите `__hash__ = None` для изменяемых объектов)
# 3. `__len__` должен быть быстрым — не выполняйте сложные вычисления

# %%
# Пример класса с хорошей реализацией всех методов
class SmartCollection:
    def __init__(self, name, items=None):
        self.name = name
        self._items = items or []
    
    def __repr__(self):
        return f"SmartCollection('{self.name}', {self._items})"
    
    def __str__(self):
        return f"Коллекция '{self.name}' с {len(self)} элементами"
    
    def __eq__(self, other):
        return (self.name == other.name and 
                self._items == other._items)
    
    def __hash__(self):
        # Хешируем только name, т.к. items может изменяться
        return hash(self.name)
    
    def __len__(self):
        return len(self._items)
    
    def add_item(self, item):
        self._items.append(item)

# Демонстрация
coll1 = SmartCollection("numbers", [1, 2, 3])
coll2 = SmartCollection("numbers", [1, 2, 3])
coll3 = SmartCollection("letters", ['a', 'b'])

print(repr(coll1))
print(str(coll1))
print(f"coll1 == coll2: {coll1 == coll2}")
print(f"coll1 == coll3: {coll1 == coll3}")
print(f"Длина coll1: {len(coll1)}")
print(f"Хеш coll1: {hash(coll1)}")

# Использование в словаре (только name используется для хеширования)
collections_dict = {coll1: "первая коллекция"}
print(f"coll2 в словаре: {coll2 in collections_dict}")  # True, т.к. name одинаковый

# %% [markdown]
# ## __bool__ — управление логическим контекстом
#
# Метод `__bool__` определяет поведение объекта в логических операциях (`if`, `while`, `and`, `or`, `not`). Он должен возвращать `True` или `False`.
#
# Если `__bool__` не определён, Python пытается вызвать `__len__`. Если объект имеет ненулевую длину — он считается `True`, иначе `False`. Если не определён ни один из них, объект всегда считается `True`.

# %%
class BooleanDemo:
    def __init__(self, value):
        self.value = value

    def __bool__(self):
        # Объект считается истинным, если value > 0
        return self.value > 0

# Демонстрация
print(bool(BooleanDemo(5)))   # True
print(bool(BooleanDemo(0)))   # False
print(bool(BooleanDemo(-3)))  # False

# %% [markdown]
# ## Методы сравнения: __lt__, __le__, __gt__, __ge__
#
# Для полной поддержки операторов сравнения (`<`, `<=`, `>`, `>=`) необходимо определить соответствующие методы. Если определить только `__eq__`, остальные операторы не будут работать корректно (будет использоваться сравнение по умолчанию, которое сравнивает идентификаторы объектов).
#
# Рассмотрим класс `Person`, который можно сравнивать по возрасту:

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __lt__(self, other):
        """Определяет поведение оператора < (меньше)"""
        if not isinstance(other, Person):
            return NotImplemented
        return self.age < other.age

    def __le__(self, other):
        """<= (меньше или равно)"""
        if not isinstance(other, Person):
            return NotImplemented
        return self.age <= other.age

    def __gt__(self, other):
        """> (больше)"""
        if not isinstance(other, Person):
            return NotImplemented
        return self.age > other.age

    def __ge__(self, other):
        """>= (больше или равно)"""
        if not isinstance(other, Person):
            return NotImplemented
        return self.age >= other.age

    def __eq__(self, other):
        """== (равно)"""
        if not isinstance(other, Person):
            return NotImplemented
        return self.age == other.age

    def __repr__(self):
        return f"Person('{self.name}', {self.age})"

# Демонстрация
p1 = Person("Анна", 25)
p2 = Person("Иван", 30)
p3 = Person("Мария", 25)

print(p1 < p2)   # True
print(p1 <= p3)  # True (равны по возрасту)
print(p1 > p2)   # False
print(p1 >= p3)  # True
print(p1 == p3)  # True
print(p1 == p2)  # False

# Благодаря определённым методам объекты можно сортировать
people = [p2, p1, p3]
people.sort()
print(people)  # [Person('Анна', 25), Person('Мария', 25), Person('Иван', 30)]

# %% [markdown]
# **Важно**: Если метод не может обработать тип `other`, следует возвращать специальное значение `NotImplemented`. Это позволяет Python попробовать вызвать соответствующий метод у `other` (например, `__radd__` для сложения), что важно для симметричных операций.
#
# ## Упрощение сравнений с @total_ordering
#
# Определение всех шести методов сравнения (`__eq__`, `__ne__`, `__lt__`, `__le__`, `__gt__`, `__ge__`) может быть утомительным. Декоратор `@total_ordering` из модуля `functools` позволяет определить только `__eq__` и один из методов сравнения (например, `__lt__`), а остальные сгенерирует автоматически.

# %%
from functools import total_ordering

@total_ordering
class PersonSimple:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __eq__(self, other):
        return self.age == other.age

    def __lt__(self, other):
        return self.age < other.age

    def __repr__(self):
        return f"PersonSimple('{self.name}', {self.age})"

# Все операторы работают автоматически
p1 = PersonSimple("Анна", 25)
p2 = PersonSimple("Иван", 30)
print(p1 <= p2)  # True (генерируется из __lt__ и __eq__)
print(p1 > p2)   # False

# %% [markdown]
# **Предостережение**: `@total_ordering` добавляет небольшое замедление, так как генерирует недостающие методы через комбинации. Для производительных вычислений лучше определить все методы вручную, но в большинстве случаев этого достаточно.
#
# ## Арифметические методы: __add__, __sub__, __mul__, __truediv__ и другие
#
# Чтобы объекты поддерживали арифметические операции (+, -, *, /, //, %, ** и т.д.), нужно определить соответствующие методы. Рассмотрим класс `Vector2D`, который поддерживает сложение, вычитание и умножение на число.

# %%
class Vector2D:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        """Сложение векторов: v + w"""
        if isinstance(other, Vector2D):
            return Vector2D(self.x + other.x, self.y + other.y)
        return NotImplemented

    def __sub__(self, other):
        """Вычитание векторов: v - w"""
        if isinstance(other, Vector2D):
            return Vector2D(self.x - other.x, self.y - other.y)
        return NotImplemented

    def __mul__(self, scalar):
        """Умножение вектора на число: v * s"""
        if isinstance(scalar, (int, float)):
            return Vector2D(self.x * scalar, self.y * scalar)
        return NotImplemented

    def __rmul__(self, scalar):
        """Умножение числа на вектор: s * v"""
        return self.__mul__(scalar)

    def __repr__(self):
        return f"Vector2D({self.x}, {self.y})"

v = Vector2D(1, 2)
w = Vector2D(3, 4)
print(v + w)        # Vector2D(4, 6)
print(v - w)        # Vector2D(-2, -2)
print(v * 3)        # Vector2D(3, 6)
print(3 * v)        # Vector2D(3, 6)  (благодаря __rmul__)

# %% [markdown]
# Обратите внимание на метод `__rmul__` — он вызывается, когда левый операнд не поддерживает операцию, а правый — поддерживает (например, `3 * v`). Аналогично существуют `__radd__`, `__rsub__` и т.д.
#
# ## Методы преобразования типов: __int__, __float__, __abs__
#
# Объекты могут определять поведение встроенных функций `int()`, `float()`, `abs()` и других. Это полезно для классов, которые представляют числа или могут быть приведены к числовому типу.
#
# Добавим в класс `Fraction` поддержку преобразования в `float` и модуля:

# %%
class Fraction:
    """Класс для работы с дробями"""

    def __init__(self, numerator, denominator):
        self.numer = numerator
        self.denom = denominator

    def __str__(self):
        return f"{self.numer}/{self.denom}"

    def __repr__(self):
        return f"Fraction({self.numer}, {self.denom})"

    def __eq__(self, other):
        if not isinstance(other, Fraction):
            return False
        return self.numer * other.denom == other.numer * self.denom

    def __hash__(self):
        return hash((self.numer, self.denom))

    def __len__(self):
        return abs(self.numer) + abs(self.denom)

    def __float__(self):
        return self.numer / self.denom

    def __abs__(self):
        return Fraction(abs(self.numer), abs(self.denom))

    def __int__(self):
        return self.numer // self.denom

# Демонстрация
f = Fraction(3, 4)
print(float(f))      # 0.75
print(abs(Fraction(-5, 2)))  # 5/2
print(int(Fraction(7, 3)))    # 2

# %% [markdown]
# ## Методы для работы с контейнерами: __getitem__, __setitem__, __delitem__, __contains__
#
# Если ваш класс представляет собой коллекцию, полезно реализовать доступ по индексу/ключу, удаление элементов и проверку вхождения через `in`. Это делает класс похожим на встроенные списки или словари.
#
# Создадим класс `SimpleList`, который оборачивает список и добавляет проверку типа при добавлении:

# %%
class SimpleList:
    def __init__(self, *args):
        self._data = list(args)

    def __getitem__(self, index):
        """Доступ по индексу: obj[i]"""
        return self._data[index]

    def __setitem__(self, index, value):
        """Присваивание по индексу: obj[i] = value"""
        self._data[index] = value

    def __delitem__(self, index):
        """Удаление элемента: del obj[i]"""
        del self._data[index]

    def __contains__(self, item):
        """Проверка вхождения: item in obj"""
        return item in self._data

    def __len__(self):
        return len(self._data)

    def append(self, item):
        self._data.append(item)

    def __repr__(self):
        return f"SimpleList{self._data}"

lst = SimpleList(1, 2, 3)
print(lst[1])        # 2
lst[1] = 99
print(lst)           # SimpleList[1, 99, 3]
print(99 in lst)     # True
print(5 in lst)      # False
del lst[0]
print(lst)           # SimpleList[99, 3]

# %% [markdown]
# ## Метод __format__ для настраиваемого форматирования
#
# Метод `__format__` вызывается функцией `format()` и при использовании f-строк с форматированием (`f"{obj:spec}"`). Он позволяет задать, как объект будет представлен в зависимости от спецификатора формата.
#
# Добавим в класс `Fraction` возможность выводить дробь в виде "числитель/знаменатель" или в десятичном виде с заданной точностью:

# %%
class Fraction:
  
    """Класс для работы с дробями"""

    def __init__(self, numerator, denominator):
        self.numer = numerator
        self.denom = denominator

    def __str__(self):
        return f"{self.numer}/{self.denom}"

    def __repr__(self):
        return f"Fraction({self.numer}, {self.denom})"

    def __eq__(self, other):
        if not isinstance(other, Fraction):
            return False
        return self.numer * other.denom == other.numer * self.denom

    def __hash__(self):
        return hash((self.numer, self.denom))

    def __len__(self):
        return abs(self.numer) + abs(self.denom)

    def __float__(self):
        return self.numer / self.denom

    def __abs__(self):
        return Fraction(abs(self.numer), abs(self.denom))

    def __int__(self):
        return self.numer // self.denom

    def __format__(self, format_spec):
        if format_spec.endswith('f'):
            # Десятичный формат
            precision = int(format_spec[:-1]) if format_spec[:-1] else 6
            return format(self.numer / self.denom, f'.{precision}f')
        elif format_spec == 'frac':
            return f"{self.numer}/{self.denom}"
        else:
            # По умолчанию используем __str__
            return str(self)

# Демонстрация
f = Fraction(2, 3)
print(format(f, 'frac'))     # "2/3"
print(format(f, '2f'))       # "0.67" (два знака после запятой)
print(f"{f:4f}")             # "0.6667" (четыре знака)

# %% [markdown]
# ## Метод __bytes__ для байтового представления
#
# Метод `__bytes__` вызывается функцией `bytes(obj)`. Он должен возвращать объект `bytes`. Это полезно для сериализации или работы с бинарными данными.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __bytes__(self):
        # Кодируем имя в UTF-8 и добавляем возраст как байт
        name_bytes = self.name.encode('utf-8')
        age_byte = bytes([self.age])  # предполагаем возраст < 256
        return name_bytes + b'|' + age_byte

p = Person("Анна", 25)
print(bytes(p))  # b'\xd0\x90\xd0\xbd\xd0\xbd\xd0\xb0|'
